# %%
from scipy import stats
import numpy as np
from matplotlib import pyplot as mp

# %%
nd=np.random.normal(40,0.5,4000)

# %%
mp.hist(nd,bins=20)
# Out:
# (array([  3.,   3.,   9.,  18.,  59., 100., 192., 300., 425., 562., 570.,
#         586., 421., 313., 212., 130.,  64.,  17.,  14.,   2.]),
#  array([38.07114745, 38.25321215, 38.43527684, 38.61734154, 38.79940623,
#         38.98147092, 39.16353562, 39.34560031, 39.52766501, 39.7097297 ,
#         39.8917944 , 40.07385909, 40.25592378, 40.43798848, 40.62005317,
#         40.80211787, 40.98418256, 41.16624726, 41.34831195, 41.53037665,
#         41.71244134]),
#  <BarContainer object of 20 artists>)

# %%
bd=np.random.binomial(300,0.48,50000)
bd
# Out:
# array([143, 147, 132, ..., 140, 142, 144])

# %%
mp.hist(bd)
# Out:
# (array([4.0000e+00, 1.5300e+02, 1.7150e+03, 6.1440e+03, 1.5743e+04,
#         1.6576e+04, 7.3030e+03, 2.1300e+03, 2.2700e+02, 5.0000e+00]),
#  array([105. , 112.7, 120.4, 128.1, 135.8, 143.5, 151.2, 158.9, 166.6,
#         174.3, 182. ]),
#  <BarContainer object of 10 artists>)

# %%
st=np.random.standard_normal(6000000)

# %%
mp.hist(st)
# Out:
# (array([1.040000e+02, 4.652000e+03, 9.237900e+04, 6.980450e+05,
#         1.991238e+06, 2.165174e+06, 8.986480e+05, 1.410890e+05,
#         8.470000e+03, 2.010000e+02]),
#  array([-5.2117654 , -4.18729974, -3.16283409, -2.13836844, -1.11390278,
#         -0.08943713,  0.93502853,  1.95949418,  2.98395983,  4.00842549,
#          5.03289114]),
#  <BarContainer object of 10 artists>)
